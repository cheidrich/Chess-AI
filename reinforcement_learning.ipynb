# %%
import importlib
import src.train_chess
importlib.reload(src.train_chess)
import matplotlib.pyplot as plt
from src.train_chess import train

import chess.svg
from IPython.display import SVG, display

# %%
losses, qs, recent_boards = train()
# Out:
# Episode: 0
# Episode: 1
# Episode: 2
# Episode: 3
# Episode: 4
# Episode: 5
# Episode: 6
# Episode: 7
# Episode: 8
# Episode: 9

# %%
for board in recent_boards:
    display(SVG(chess.svg.board(board=board)))

# %%
plt.figure(figsize=(16,6))
plt.plot(losses)
plt.xlabel("Training Step")
plt.ylabel("Q-Value Loss")
plt.title("Q-Loss over Time")
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(16,6))
plt.plot(qs)
plt.xlabel("Training Step")
plt.ylabel("Q-Value Loss")
plt.title("Q-Loss over Time")
plt.grid(True)
plt.show()
